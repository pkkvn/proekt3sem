# %%
import matplotlib.pyplot as plt;
import numpy as np;

time, v, x = np.loadtxt('text.txt', unpack=True)

fig, (g1) = plt.subplots(1)
          
g1.scatter(time, x, 1)
plt.grid()
#g3.scatter(time, ksi, 1)
             
#plt.xlabel('$\phi$')
#plt.ylabel('$\ksi$') 
plt.show()

# %%
plt.title("x(t)")
plt.plot(time[0:10000], x[0:10000])
plt.grid()
plt.show()

# %%
w, A = np.loadtxt('text2.txt', unpack=True)

fig, (g1) = plt.subplots(1)
          
g1.scatter(w, A, 1)
plt.grid()
#g3.scatter(time, ksi, 1)

plt.title("A(w)")

#plt.xlabel('$\phi$')
#plt.ylabel('$\ksi$') 
plt.show()

# %%
data1 = np.loadtxt("text2.txt").T


w = data1[0]
A = data1[1]

A_max, index_max = max(A), list(A).index(max(A))
w0 = w[index_max]

print(w0)
# Out:
# 0.991
