# %%
import matplotlib.pyplot as plt;
import numpy as np;

time, phi, ksi, energy, lnE, lnt = np.loadtxt('text.txt', unpack=True)

fig, (g1) = plt.subplots(1)

             
g1.scatter(phi, ksi, 1)
plt.grid()
#g2.scatter(time, energy, 1)
#plt.grid()
#g3.scatter(time, ksi, 1)
             
#plt.xlabel('$\phi$')
#plt.ylabel('$\ksi$') 
plt.show()

# %%
fig, (g2) = plt.subplots(1)
g2.scatter(time, energy, 1)
plt.grid()
plt.show()

# %%
fig, (g3) = plt.subplots(1)
g3.scatter(time, phi, 1)
plt.grid()
plt.show()

# %%
fig, (g4) = plt.subplots(1)
g4.scatter(time, ksi, 1)
plt.grid()
plt.show()

# %%
fig, (g5) = plt.subplots(1)
g5.scatter(time, lnE, 1)
plt.grid()
plt.show()
